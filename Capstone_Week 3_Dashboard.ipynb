# %%
'''
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
'''
# Out:
#   File "C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/249173471.py", line 5
#     !pip install --upgrade plotly
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px

# %%
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# %%
# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(id='site-dropdown',
                                            options=[
                                                         {'label': 'ALL SITES', 'value': 'ALL'},
                                                         {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                         {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                         {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                         {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                    ],
                                            #value='ALL',
                                            placeholder='Please Select a Launch Site', 
                                            searchable=True),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',
                                                min=0, max=10000, step=1000,
                                                value=[min_payload, max_payload],
                                                marks={0: '0', 2500:'2500',5000:'5000',
                                                7500:'7500', 10000: '10000'}),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart'))
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(
    Output(component_id='success-pie-chart', component_property='figure'),
    Input(component_id='site-dropdown', component_property='value'))

def build_graph(site_dropdown):
    if site_dropdown == 'ALL':
        piechart = px.pie(data_frame = spacex_df, names='Launch Site', values='class' , title='Total Launches for All Sites')
        return piechart
    else:
        specific_df=spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        piechart = px.pie(data_frame = specific_df, names='class', title='Total Launch for a Specific Site')
        return piechart

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(
    Output(component_id='success-payload-scatter-chart', component_property='figure'),
    [Input(component_id='site-dropdown', component_property='value'),
    Input(component_id='payload-slider', component_property='value')])

def update_graph(site_dropdown, payload_slider):
    if site_dropdown == 'ALL':
        filtered_data = spacex_df[(spacex_df['Payload Mass (kg)'] >= payload_slider[0])
        & (spacex_df['Payload Mass (kg)'] <= payload_slider[1])]
        scatterplot = px.scatter(data_frame=filtered_data, x="Payload Mass (kg)", y="class", 
        color="Booster Version Category")
        return scatterplot
    else:
        specific_df=spacex_df.loc[spacex_df['Launch Site'] == site_dropdown]
        filtered_data = specific_df[(specific_df['Payload Mass (kg)'] >= payload_slider[0])
        & (spacex_df['Payload Mass (kg)'] <= payload_slider[1])]
        scatterplot = px.scatter(data_frame=filtered_data, x="Payload Mass (kg)", y="class", 
        color="Booster Version Category")
        return scatterplot

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [30/Jul/2022 08:57:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:21] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:21] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:21] "GET /_favicon.ico?v=2.5.1 HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:21] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:21] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:21] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:21] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:23] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 08:57:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 08:57:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:37:31] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:37:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:37:35] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:37:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:37:40] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:37:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:37:42] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:37:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:37:46] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:37:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:37:51] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:37:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:38:00] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:38:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:38:04] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:38:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:38:09] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:38:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:38:18] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:38:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:39:17] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:39:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:39:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:39:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [30/Jul/2022 14:40:04] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:40:04] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:57:49] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 14:58:26] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:15:32] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:16:52] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:18:24] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:18:28] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:18:52] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:18:57] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:19:02] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:19:07] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:19:11] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:20:25] "POST /_dash-update-component HTTP/1.1" 200 -
# C:\Users\A5C9XZZ\AppData\Local\Temp\1/ipykernel_53868/3683662441.py:72: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# 127.0.0.1 - - [30/Jul/2022 15:20:29] "POST /_dash-update-component HTTP/1.1" 200 -
